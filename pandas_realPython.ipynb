# %% [markdown]
# # practice Pandas from RealPython

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/legislators-historical.csv')
df
# Out:
#          last_name  first_name middle_name suffix nickname         full_name  \
# 0          Bassett     Richard         NaN    NaN      NaN               NaN
# 1            Bland  Theodorick         NaN    NaN      NaN               NaN
# 2            Burke     Aedanus         NaN    NaN      NaN               NaN
# 3          Carroll      Daniel         NaN    NaN      NaN               NaN
# 4           Clymer      George         NaN    NaN      NaN               NaN
# ...            ...         ...         ...    ...      ...               ...
# 12051        Young         Don          E.    NaN      NaN         Don Young
# 12052  Fortenberry        Jeff        Lane    NaN      NaN  Jeff Fortenberry
# 12053         Vela     Filemon         NaN    NaN      NaN      Filemon Vela
# 12054         Reed         Tom          W.    NaN      NaN          Tom Reed
# 12055      Delgado     Antonio         NaN    NaN      NaN   Antonio Delgado
#
# ...

# %%
df.groupby('state').count()
# Out:
#        last_name  first_name  middle_name  suffix  nickname  full_name  \
# state
# AK            17          17           13       0         2          2
# AL           209         209          154      12         5          7
# AR           117         117           92       8         4          3
# AS             2           2            2       0         0          1
# AZ            49          49           35       4         2          9
# CA           368         368          291      12        14         40
# CO            92          92           76       1         6          5
# CT           240         240          146       7         2          2
# DC             2           2            2       0         0          0
# DE            97          97           70      15         0          1
# DK             9           9            8       0         0          0
# FL           161         161          103      14        14         31
# ...

# %%
by_state =  df.groupby('state')['last_name', 'middle_name'].count()
by_state
# Out:
# /tmp/ipykernel_249304/2273736461.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   by_state =  df.groupby('state')['last_name', 'middle_name'].count()
#        last_name  middle_name
# state
# AK            17           13
# AL           209          154
# AR           117           92
# AS             2            2
# AZ            49           35
# CA           368          291
# CO            92           76
# CT           240          146
# DC             2            2
# DE            97           70
# DK             9            8
# FL           161          103
# GA           317          217
# GU             4            4
# HI            24           20
# IA           205          168
# ID            59           45
# IL           488          390
# IN           343          256
# KS           143          109
# KY           373          261
# LA           199          149
# ...

# %%
df.groupby(['state', 'gender'])['last_name', 'middle_name'].count().head(50)
# Out:
# /tmp/ipykernel_249304/2715983420.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['state', 'gender'])['last_name', 'middle_name'].count().head(50)
#               last_name  middle_name
# state gender
# AK    M              17           13
# AL    F               4            3
#       M             205          151
# AR    F               5            5
#       M             112           87
# AS    M               2            2
# AZ    F               4            1
#       M              45           34
# CA    F              26           13
#       M             342          278
# CO    F               3            2
#       M              89           74
# CT    F               6            6
#       M             234          140
# DC    M               2            2
# DE    M              97           70
# DK    M               9            8
# ...

# %%
df.groupby(['state', 'gender'], as_index=False)['last_name', 'middle_name'].count().head(6)
# Out:
# /tmp/ipykernel_249304/3872729061.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['state', 'gender'], as_index=False)['last_name', 'middle_name'].count().head(6)
#   state gender  last_name  middle_name
# 0    AK      M         17           13
# 1    AL      F          4            3
# 2    AL      M        205          151
# 3    AR      F          5            5
# 4    AR      M        112           87
# 5    AS      M          2            2
